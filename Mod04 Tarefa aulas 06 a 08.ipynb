# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'
r = requests.get(url)
data_json = r.json()
print(data_json['items'])
# Out:
# [{'id_pleito': 4997, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.000020/2010-11', 'data_protocolo': '2010-04-19T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'PMAE', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 9982000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '20/04/2010'}, {'id_pleito': 7085, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000493/2012-72', 'data_protocolo': '2012-04-16T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Corporação Andin
# ...

# %%
r.status_code
# Out:
# 200

# %%
participacoes_RJ = pd.DataFrame(data_json['items'])
participacoes_RJ
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0        4997           Estado  Rio de Janeiro        33  RJ
# 1        7085           Estado  Rio de Janeiro        33  RJ
# 2        5516           Estado  Rio de Janeiro        33  RJ
# 3       13624           Estado  Rio de Janeiro        33  RJ
# 4       13483           Estado  Rio de Janeiro        33  RJ
# 5       13629           Estado  Rio de Janeiro        33  RJ
# 6        5933           Estado  Rio de Janeiro        33  RJ
# 7        5952           Estado  Rio de Janeiro        33  RJ
# 8        7187           Estado  Rio de Janeiro        33  RJ
# 9        9042           Estado  Rio de Janeiro        33  RJ
# 10      11306           Estado  Rio de Janeiro        33  RJ
# 11      21388           Estado  Rio de Janeiro        33  RJ
# 12       9050           Estado  Rio de Janeiro        33  RJ
# 13       6660           Estado  Rio de Janeiro        33  RJ
# ...

# %%
participacoes_RJ['status'].value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %%
participacoes_RJ['status'].value_counts(3)
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    0.653846
# Deferido                                                 0.269231
# Arquivado a pedido                                       0.057692
# Arquivado por decurso de prazo                           0.019231
# Name: status, dtype: float64

# %%
participacoes_RJ['ano_status'] = participacoes_RJ['data_status'].str.slice(start=6)
participacoes_RJ
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0        4997           Estado  Rio de Janeiro        33  RJ
# 1        7085           Estado  Rio de Janeiro        33  RJ
# 2        5516           Estado  Rio de Janeiro        33  RJ
# 3       13624           Estado  Rio de Janeiro        33  RJ
# 4       13483           Estado  Rio de Janeiro        33  RJ
# 5       13629           Estado  Rio de Janeiro        33  RJ
# 6        5933           Estado  Rio de Janeiro        33  RJ
# 7        5952           Estado  Rio de Janeiro        33  RJ
# 8        7187           Estado  Rio de Janeiro        33  RJ
# 9        9042           Estado  Rio de Janeiro        33  RJ
# 10      11306           Estado  Rio de Janeiro        33  RJ
# 11      21388           Estado  Rio de Janeiro        33  RJ
# 12       9050           Estado  Rio de Janeiro        33  RJ
# 13       6660           Estado  Rio de Janeiro        33  RJ
# ...

# %%
participacoes_RJ['ano_status'].value_counts(3)
# Out:
# 2012    0.211538
# 2009    0.173077
# 2013    0.134615
# 2011    0.115385
# 2002    0.076923
# 2014    0.076923
# 2016    0.076923
# 2010    0.057692
# 2006    0.038462
# 2008    0.038462
# Name: ano_status, dtype: float64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
url2 = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=MG&tipo_interessado=Estado'
MG1 = requests.get(url2)
MG2 = MG1.json()
print(MG2['items'])
# Out:
# [{'id_pleito': 9197, 'tipo_interessado': 'Estado', 'interessado': 'Minas Gerais', 'cod_ibge': 31, 'uf': 'MG', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.000924/2009-03', 'data_protocolo': '2010-03-10T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Interamericano de Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 50000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '01/04/2010'}, {'id_pleito': 13441, 'tipo_interessado': 'Estado', 'interessado': 'Minas Gerais', 'cod_ibge': 31, 'uf': 'MG', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '19405.000001/2005-42', 'data_protocolo': '2005-08-16T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Nor
# ...

# %%
participacoes_MG = pd.DataFrame(MG2['items'])
participacoes_MG
# Out:
#     id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0        9197           Estado  Minas Gerais        31  MG
# 1       13441           Estado  Minas Gerais        31  MG
# 2       13641           Estado  Minas Gerais        31  MG
# 3       12286           Estado  Minas Gerais        31  MG
# 4       13447           Estado  Minas Gerais        31  MG
# 5       20458           Estado  Minas Gerais        31  MG
# 6        7280           Estado  Minas Gerais        31  MG
# 7        4926           Estado  Minas Gerais        31  MG
# 8       11696           Estado  Minas Gerais        31  MG
# 9        6811           Estado  Minas Gerais        31  MG
# 10      13549           Estado  Minas Gerais        31  MG
# 11       7419           Estado  Minas Gerais        31  MG
# 12       8255           Estado  Minas Gerais        31  MG
# 13      10294           Estado  Minas Gerais        31  MG
# 14       6917           Estado  Minas Gerais        31  MG
# ...

# %%
participacoes_MG[['tipo_interessado','uf']]
# Out:
#    tipo_interessado  uf
# 0            Estado  MG
# 1            Estado  MG
# 2            Estado  MG
# 3            Estado  MG
# 4            Estado  MG
# 5            Estado  MG
# 6            Estado  MG
# 7            Estado  MG
# 8            Estado  MG
# 9            Estado  MG
# 10           Estado  MG
# 11           Estado  MG
# 12           Estado  MG
# 13           Estado  MG
# 14           Estado  MG
# 15           Estado  MG
# 16           Estado  MG
# 17           Estado  MG
# 18           Estado  MG
# 19           Estado  MG
# 20           Estado  MG
# 21           Estado  MG
# 22           Estado  MG
# 23           Estado  MG
# 24           Estado  MG
# 25           Estado  MG
# 26           Estado  MG
# 27           Estado  MG
# 28           Estado  MG
# 29           Estado  MG
# 30           Estado  MG
# 31           Estado  MG
# 32           Estado  MG
# 33           Estado  MG
# 34           Estado  MG
# 35           Estado  MG
# 36           Estado  MG
# ...

# %%
participacoes_MG['status_fl'] = 0

# %%
participacoes_MG.loc[participacoes_MG['status'] ==  'Arquivado por decurso de prazo', 'status_fl'] = 1

# %%
participacoes_MG['status_fl'].sum()
# Out:
# 1

# %%
url3 = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Município'
BA1 = requests.get(url3)
BA2 = BA1.json()
print(BA2['items'])
# Out:
# [{'id_pleito': 30110, 'tipo_interessado': 'Município', 'interessado': 'Camaçari', 'cod_ibge': 2905701, 'uf': 'BA', 'num_pvl': 'PVL02.002423/2018-81', 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.109202/2018-04', 'data_protocolo': '2019-02-14T21:17:27Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Multissetorial', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Corporação Andina de Fomento', 'moeda': 'Dólar dos EUA', 'valor': 80000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '19/02/2019'}, {'id_pleito': 45385, 'tipo_interessado': 'Município', 'interessado': 'Crisópolis', 'cod_ibge': 2909604, 'uf': 'BA', 'num_pvl': 'PVL02.001569/2021-13', 'status': 'Deferido (PVL-IF)', 'num_processo': None, 'data_protocolo': None, 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Agê
# ...

# %%
participacoes_BA = pd.DataFrame(BA2['items'])
participacoes_BA.loc[participacoes_BA['status'] ==  'Deferido']
# Out:
#      id_pleito tipo_interessado        interessado  cod_ibge  uf  \
# 2        46389        Município          Barreiras   2903201  BA
# 14       46553        Município           Iraquara   2914406  BA
# 15       37368        Município          Barreiras   2903201  BA
# 17       13054        Município    Barra da Estiva   2902807  BA
# 19       18588        Município             Ilhéus   2913606  BA
# ..         ...              ...                ...       ...  ..
# 841       9237        Município            Boquira   2904100  BA
# 842      11762        Município          Itapicuru   2916500  BA
# 843      50929        Município         Maragogipe   2920601  BA
# 844      32588        Município  Bom Jesus da Lapa   2903904  BA
# 848      33253        Município   Lauro de Freitas   2919207  BA
#
#                   num_pvl    status          num_processo  \
# 2    PVL02.002181/2021-21  Deferido  17944.103189/2021-77
# 14   PVL02.002461/2021-30  Deferido  17944.103301/2021-70
# ...

# %%
participacoes_BA['interessado'].value_counts()
# Out:
# Camaçari                  18
# Salvador                  16
# Luís Eduardo Magalhães    15
# Vitória da Conquista      14
# Amargosa                  13
#                           ..
# Boninal                    1
# Caetanos                   1
# Caldeirão Grande           1
# Andorinha                  1
# Itapicuru                  1
# Name: interessado, Length: 282, dtype: int64

# %%
url4 = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Estado'
BA = requests.get(url3)
BAA = BA.json()
print(BAA['items'])
# Out:
# [{'id_pleito': 30110, 'tipo_interessado': 'Município', 'interessado': 'Camaçari', 'cod_ibge': 2905701, 'uf': 'BA', 'num_pvl': 'PVL02.002423/2018-81', 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.109202/2018-04', 'data_protocolo': '2019-02-14T21:17:27Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Multissetorial', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Corporação Andina de Fomento', 'moeda': 'Dólar dos EUA', 'valor': 80000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '19/02/2019'}, {'id_pleito': 45385, 'tipo_interessado': 'Município', 'interessado': 'Crisópolis', 'cod_ibge': 2909604, 'uf': 'BA', 'num_pvl': 'PVL02.001569/2021-13', 'status': 'Deferido (PVL-IF)', 'num_processo': None, 'data_protocolo': None, 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Agê
# ...

# %%
participacoes_BH = pd.DataFrame(BAA['items'])
participacoes_BH
# Out:
#      id_pleito tipo_interessado         interessado  cod_ibge  uf  \
# 0        30110        Município            Camaçari   2905701  BA
# 1        45385        Município          Crisópolis   2909604  BA
# 2        46389        Município           Barreiras   2903201  BA
# 3        42878        Município            Jacobina   2917508  BA
# 4        42877        Município  Brotas de Macaúbas   2904506  BA
# ..         ...              ...                 ...       ...  ..
# 845      29853        Município        Capim Grosso   2906873  BA
# 846      12573        Município          Alagoinhas   2900702  BA
# 847      56349        Município              Seabra   2929909  BA
# 848      33253        Município    Lauro de Freitas   2919207  BA
# 849      10167        Município         Santa Luzia   2928059  BA
#
#                   num_pvl                                             status  \
# 0    PVL02.002423/2018-81  Encaminhado à PGFN com manifestação técnica fa...
# ...

# %%
participacoes_BH.to_csv('Participacoes_Bahia.csv')
